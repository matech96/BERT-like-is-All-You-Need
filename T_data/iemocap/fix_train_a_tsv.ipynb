# %%
import os

# %%
with open("train_t.tsv") as f:
    lines = f.readlines()
lines = [l.strip() for l in lines]

# %%
new_a = [f"{l[:-4]}.wav\n" for l in lines]
new_a
# Out:
# ['1299_s_2_neu.wav\n',
#  '1589_s_2_ang.wav\n',
#  '1875_s_2_ang.wav\n',
#  '2162_s_3_neu.wav\n',
#  '2456_s_3_hap.wav\n',
#  '2729_s_3_hap.wav\n',
#  '2995_s_3_neu.wav\n',
#  '324_s_1_sad.wav\n',
#  '3507_s_4_exc.wav\n',
#  '38_s_1_neu.wav\n',
#  '41_s_1_sad.wav\n',
#  '687_s_1_neu.wav\n',
#  '0_s_1_ang.wav\n',
#  '1000_s_1_hap.wav\n',
#  '1001_s_1_hap.wav\n',
#  '1002_s_1_hap.wav\n',
#  '1003_s_1_hap.wav\n',
#  '1004_s_1_hap.wav\n',
#  '1005_s_1_hap.wav\n',
#  '1006_s_1_hap.wav\n',
#  '1007_s_1_hap.wav\n',
#  '1008_s_1_exc.wav\n',
#  '1009_s_1_hap.wav\n',
#  '100_s_1_ang.wav\n',
#  '1010_s_1_hap.wav\n',
#  '1011_s_1_hap.wav\n',
#  '1012_s_1_hap.wav\n',
#  '1013_s_1_hap.wav\n',
#  '1014_s_1_hap.wav\n',
#  '2600_s_3_ang.wav\n',
#  '2601_s_3_ang.wav\n',
#  '2602_s_3_neu.wav\n',
#  '2603_s_3_ang.wav\n',
#  '2604_s_3_ang.wav\n',
#  '2605_s_3_ang.wav\n',
#  '2606_s_3_ang.wav\n',
#  '2607_s_3_ang.wav\n',
#  '2608_s_3_ang.wav\n',
#  '2609_s_3_ang.wav\n',
#  '260_s_1_ang.wav\n',
# ...

# %%
os.rename("train_a.tsv", "train_a_org.tsv")

# %%
with open("train_a.tsv", "w+") as f:
    f.writelines(new_a)
